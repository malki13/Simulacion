# %% [markdown]
# # DESARROLLO DEL MODELO Covid-19 infección en Ecuador.
#
# ## Formulacion del problema
#
# Esta simulacion se usara para presentar el avance de la enfermedad covid-19 en el ecuador, donde se busca predecir a travez de una regresion lineal y logaritmica el avance de la enfermedad a travez de datos que se tiene de personas que tuvieron la enfermedad y las personas que se han recuperado. Los datos recopildos sivern para poder realizar una simulacion del avance de la enfermedad y predecir el comportamiento y avance de la misma.
#
# ## Definición del sistema
# Se procede a simular el avance de la enfermedad covid-19 dentro del ecuador. Para este analisis se utilizaran datos recopilados de acuerdo a fechas sobre el numero de casos y numero de muertos que se dieron desde el mes de marzo.
#
#
# ## Formulación del modelo
#
# Para el analisis y predicion de avance de la enfermedad se empleara en modelo lineal y el modelo logistico
# - Modelo Lineal: La regresión lineal es un algoritmo de aprendizaje supervisado que se utiliza en Machine Learning y en estadística. En su versión más sencilla, lo que haremos es «dibujar una recta» que nos indicará la tendencia de un conjunto de datos continuos.
# - Modelo Logistico: El modelo logístico se ha utilizado ampliamente para describir el crecimiento de una población. Una infección puede describirse como el crecimiento de la población de un agente patógeno, por lo que un modelo logístico parece razonable
#
# ## Colección de datos .
#
# Los datos o coleccion de datos utilizados para el analisis de la enferdad del covid-19 en el ecuador se utilizara de la pagina ..... Este archivo contiene datos de la enfermedad y su avance a travez del mundo. De este dataset se utilizara los datos de Ecuador.
# ![datoscovud.PNG](attachment:datoscovud.PNG)
#
# Los datos que nos descargamos en un archivo csv se porceden a subir en un arreglo que se puede manipular para la aplicacion en los modelos lineal y logistico.
# ![datos.PNG](attachment:datos.PNG)
#
# ## Implementación del modelo en el ordenador
# Para el modelo lineal se implemeta el calculo de la recta con la ayuda de las librerias sklearn que permite implementar la la funcion de la recta y obtener la predicion de acuerdo a los datos que se tiene en nuestro arreglo de datos de la enfermedad covid-19.
#
# Ecuacion de la recta:
# Y = mX + b
#
# Donde Y es el resultado, X es la variable, m la pendiente (o coeficiente) de la recta y b la constante
#
# ![modli1.PNG](attachment:modli1.PNG)
#
# Modelo logistico Formula
# ![for.PNG](attachment:for.PNG)
#
# El modelo logistico es implemetado al igual con los datos que se obtienen de nuestro archivo csv.
# ![modlog1.PNG](attachment:modlog1.PNG)
#
# ## Verificación .
#
# Para la validacion y verificacion de errores y que se obtengan y se trabajen con los valores esperados y requeridos se utilizo jupyterLab en donde utilizamos la erramienta de debugging para verificacion de codigo.
#
# ![debugger.PNG](attachment:debugger.PNG)
#
#
# ## Diseño de experimentos .
#
# Para poder realizar la experimentacion utilizaremos datos en el tiempo para la prediccion de valores como pueden ser de contagios en 50 dias y muertes que se puedan dar. Para esto se utilizara los datos del archivo csv y los modelos lineal y logistico.
#
# ## Experimentación .
# Se realizan simulaciones de acuerdo al modelo logistico y modelo lineal. Se recolectan y procesan los resultados.
# ![exp1.PNG](attachment:exp1.PNG)
# ![exp2.PNG](attachment:exp2.PNG)
# ![exp3.PNG](attachment:exp3.PNG)
# ![exp4.PNG](attachment:exp4.PNG)
#
# ## Interpretación .
#
# Para tener una mejor interpretacion y visualizacion de los datos se utilizan graficas que permiten visualizar la preficion y el modelo empleado para asi tener un entendimiento y ver si la prediccion se asemeja a los datos que se tiene.
# ![pr1.PNG](attachment:pr1.PNG)
# ![pr2.PNG](attachment:pr2.PNG)
# ![pr3.PNG](attachment:pr3.PNG)
# ![pr4.PNG](attachment:pr4.PNG)
#
# ## CONCLICIONES
# Para el desarrollo de un modelo de simulacion se puede emplear y seguir los pasos descritos ayudara a tener y desarrollar un modelo efectivo que se emplear para aplicaciones efectivas.
